# %%
using Plots

# %%
X = ["campusbkstr", "campbkweb", "onlinebkstr", "offcampbkstr", "rentedtxtbk","ebooks","no txtbks"];
Y = [576, 48, 240, 168, 36, 12, 72]
 
P = bar(X,Y, title = "where students buy textbooks", xlabel = ["where books purchased"],ylabel = ["frequency"])

# %%
X = ["security", "maintenance", "flight op", "hazardous", "other"];
Y = [0.43, 0.39, 0.06, 0.03, 0.09]
 
P = pie(X,Y, title = "how safe is that jet")
