# %%
using Plots

# %%
X = ["edison", "florida am", "flor atlantic", "gulf coast", "international","florida state","new college", "pensacola", "santa fe", "tallahasee", "central florida", "unv of florida", "north florida", "south florida", "west florida"];
Y = [4, 14, 4, 3, 9, 31, 1, 3, 1, 2, 26, 18, 2, 2, 2]
 
P = pie(X,Y, title = "crime on college campus")

# %%
using DataFrames

# %%
df = DataFrame(college = ["edison", "florida am", "flor atlantic", "gulf coast", "international","florida state","new college", "pensacola", "santa fe", "tallahasee", "central florida", "unv of florida", "north florida", "south florida", "west florida"], students = [17107,13204,25246,12851,44616,41067,845,11531,15493,15090,58465,49589,16198,4310,11982], crimes = [4, 14, 4, 3, 9, 31, 1, 3, 1, 2, 26, 18, 2, 2, 2])
# Out:
# 15×3 DataFrame
#  Row │ college          students  crimes
#      │ String           Int64     Int64
# ─────┼───────────────────────────────────
#    1 │ edison              17107       4
#    2 │ florida am          13204      14
#    3 │ flor atlantic       25246       4
#    4 │ gulf coast          12851       3
#    5 │ international       44616       9
#    6 │ florida state       41067      31
#    7 │ new college           845       1
#    8 │ pensacola           11531       3
#    9 │ santa fe            15493       1
#   10 │ tallahasee          15090       2
#   11 │ central florida     58465      26
#   12 │ unv of florida      49589      18
#   13 │ north florida       16198       2
#   14 │ south florida        4310       2
#   15 │ west florida        11982       2
